# %%
print = 'hello world'

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.8 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.8 MB 2.3 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.8 MB 2.2 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.8 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.8 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.8 MB 2.0 MB/s eta 0:00:04
#    --------------- ------------------------ 3.7/9.8 MB 1.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.9/9.8 MB 1.9 MB/s eta 0:00:04
#    ------------------ --------------------- 4.5/9.8 MB 1.9 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.8 MB 1.9 MB/s eta 0:00:03
# ...

# %%
import importlib
import os

importlib.reload(os)

print(os.getcwd())
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Microsoft VS Code

# %%
import pandas as pd

df = pd.read_csv("C:/Users/ASUS/Downloads/directory.csv")

# %%
df.tail(50)
# Out:
#            Brand  Store Number                          Store Name  \
# 25550  Starbucks    9619-97642              Eastridge Mall- Casper
# 25551  Starbucks  79668-108627               Ridley's Casper #1132
# 25552  Starbucks  11862-103659   Cy Ave & SW Wyoming Blvd - Casper
# 25553  Starbucks  28265-237406           King Soopers-Cheyenne #79
# 25554  Starbucks   74427-94041              Safeway-Cheyenne #2667
# 25555  Starbucks   73370-24376         Albertsons - Cheyenne #0065
# 25556  Starbucks   73277-27188         Albertsons - Cheyenne #0066
# 25557  Starbucks  29314-251304   Yellowstone and Storey - Cheyenne
# 25558  Starbucks  11082-102939  21st & Central Avenue-Cheyenne, WY
# 25559  Starbucks    6515-63127              Dell Range Marketplace
# 25560  Starbucks  17716-126790               Albertsons-Cody #2061
# 25561  Starbucks   73334-24378         Albertsons - Gillette #0067
# 25562  Starbucks  11320-103719     I-90 & S Douglas Hwy - Gillette
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            Brand  Store Number        Store Name Ownership Type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           Street Address  \
# 0                                      Av. Meritxell, 96
# ...

# %%
df.describe(include='all')
# Out:
#             Brand  Store Number Store Name Ownership Type  \
# count       25600         25600      25600          25600
# unique          4         25599      25364              4
# top     Starbucks  19773-160973  Starbucks  Company Owned
# freq        25249             2        224          11932
# mean          NaN           NaN        NaN            NaN
# std           NaN           NaN        NaN            NaN
# min           NaN           NaN        NaN            NaN
# 25%           NaN           NaN        NaN            NaN
# 50%           NaN           NaN        NaN            NaN
# 75%           NaN           NaN        NaN            NaN
# max           NaN           NaN        NaN            NaN
#
#                             Street Address   City State/Province Country  \
# count                                25598  25585          25600   25600
# unique                               25353   5469            338      73
# ...

# %%
df.isnull().sum()
# Out:
# Brand                0
# Store Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6861
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %%
df.mean
# Out:
# <bound method DataFrame.mean of            Brand  Store Number        Store Name Ownership Type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           Street Address  \
# 0                                      Av. Meritxell, 96
# ...

# %%
df['Store_Count'] = df.groupby('City')['Brand'].transform('count')
print(df.head())
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude  \
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['brand', 'store_number', 'store_name', 'ownership_type',
#        'street_address', 'city', 'state/province', 'country', 'postcode',
#        'phone_number', 'timezone', 'longitude', 'latitude', 'store_count'],
#       dtype='str')

# %%
import pandas as pd

# %%
df =pd.read_csv("C:/Users/ASUS/Downloads/directory.csv")

# %%
labels = ['Low', 'Medium', 'High']

df['Latitude_Level'] = pd.qcut(
    df['Latitude'],
    q=3,
    labels=labels
)

print(df[['Latitude', 'Latitude_Level']].head())
# Out:
#    Latitude Latitude_Level
# 0     42.51           High
# 1     25.42            Low
# 2     25.39            Low
# 3     24.48            Low
# 4     24.51            Low

# %%
stores_by_country = df.groupby('Country').size()
print(stores_by_country)
# Out:
# Country
# AD        1
# AE      144
# AR      108
# AT       18
# AU       22
#       ...
# TT        3
# TW      394
# US    13608
# VN       25
# ZA        3
# Length: 73, dtype: int64

# %%
stores_by_city = df.groupby('City').size()
print(stores_by_city)
# Out:
# City
# 's-Hertogenbosch      1
# 1~2F                  1
# 2-3-6 Kyonancho       1
# 330-9501              1
# 438-1 Fujisawa        1
#                    ...
# 부산                   16
# 서울                  136
# 울산                    2
# 인천                    9
# 충청남도                  1
# Length: 5469, dtype: int64

# %%
print(df['Ownership Type'].value_counts())
# Out:
# Ownership Type
# Company Owned    11932
# Licensed          9375
# Joint Venture     3976
# Franchise          317
# Name: count, dtype: int64

# %%
df[['Brand', 'Store Number']].head(10)
# Out:
#        Brand  Store Number
# 0  Starbucks  47370-257954
# 1  Starbucks  22331-212325
# 2  Starbucks  47089-256771
# 3  Starbucks  22126-218024
# 4  Starbucks  17127-178586
# 5  Starbucks  17688-182164
# 6  Starbucks  18182-182165
# 7  Starbucks  23359-229184
# 8  Starbucks   30781-99022
# 9  Starbucks  20423-205465

# %%
df[['Brand', 'Store Name', 'Street Address']].head(10)
# Out:
#        Brand                Store Name                   Street Address
# 0  Starbucks             Meritxell, 96                Av. Meritxell, 96
# 1  Starbucks          Ajman Drive Thru             1 Street 69, Al Jarf
# 2  Starbucks                 Dana Mall     Sheikh Khalifa Bin Zayed St.
# 3  Starbucks                Twofour 54                  Al Salam Street
# 4  Starbucks              Al Ain Tower  Khaldiya Area, Abu Dhabi Island
# 5  Starbucks  Dalma Mall, Ground Floor             Dalma Mall, Mussafah
# 6  Starbucks       Dalma Mall, Level 1             Dalma Mall, Mussafah
# 7  Starbucks        Debenhams Yas Mall                       Yas Island
# 8  Starbucks          Khalidiya Street                    Khalidiya St.
# 9  Starbucks         Eastern Mangroves   Al Salam Street, The Mangroves

# %%
df[['Brand', 'Store Name', 'Street Address', 'Country','Phone Number']].head(10)
# Out:
#        Brand                Store Name                   Street Address  \
# 0  Starbucks             Meritxell, 96                Av. Meritxell, 96
# 1  Starbucks          Ajman Drive Thru             1 Street 69, Al Jarf
# 2  Starbucks                 Dana Mall     Sheikh Khalifa Bin Zayed St.
# 3  Starbucks                Twofour 54                  Al Salam Street
# 4  Starbucks              Al Ain Tower  Khaldiya Area, Abu Dhabi Island
# 5  Starbucks  Dalma Mall, Ground Floor             Dalma Mall, Mussafah
# 6  Starbucks       Dalma Mall, Level 1             Dalma Mall, Mussafah
# 7  Starbucks        Debenhams Yas Mall                       Yas Island
# 8  Starbucks          Khalidiya Street                    Khalidiya St.
# 9  Starbucks         Eastern Mangroves   Al Salam Street, The Mangroves
#
#   Country Phone Number
# 0      AD    376818720
# 1      AE          NaN
# 2      AE          NaN
# 3      AE          NaN
# 4      AE          NaN
# 5      AE          NaN
# ...

# %%
import importlib
import os

importlib.reload(os)

print(os.getcwd())
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Microsoft VS Code

# %%
df.tail(100)
# Out:
#            Brand  Store Number                   Store Name Ownership Type  \
# 25500  Starbucks  19808-202245        Prairie Lakes & Grand  Company Owned
# 25501  Starbucks  10928-103119  Silver Spring & Highway 164  Company Owned
# 25502  Starbucks  25706-240885                        Tomah  Company Owned
# 25503  Starbucks    9807-98204         Moreland & Delafield  Company Owned
# 25504  Starbucks  29758-251827          Meijer 276 Waukesha       Licensed
# ...          ...           ...                          ...            ...
# 25595  Starbucks  21401-212072                          Rex       Licensed
# 25596  Starbucks  24010-226985                     Panorama       Licensed
# 25597  Starbucks  47608-253804                Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809                 Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286               Mall of Africa       Licensed
#
#                                           Street Address  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25600 entries, 0 to 25599
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           25600 non-null  str
#  1   Store Number    25600 non-null  str
#  2   Store Name      25600 non-null  str
#  3   Ownership Type  25600 non-null  str
#  4   Street Address  25598 non-null  str
#  5   City            25585 non-null  str
#  6   State/Province  25600 non-null  str
#  7   Country         25600 non-null  str
#  8   Postcode        24078 non-null  str
#  9   Phone Number    18739 non-null  str
#  10  Timezone        25600 non-null  str
#  11  Longitude       25599 non-null  float64
#  12  Latitude        25599 non-null  float64
# dtypes: float64(2), str(11)
# memory usage: 2.5 MB

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python313\python.exe

# %%
# %pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc

print(pyodbc.version)
print(pyodbc.drivers())
# Out:
# 5.3.0
# ['SQL Server', 'ODBC Driver 17 for SQL Server', 'ODBC Driver 18 for SQL Server']

# %%
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=.\\SQLEXPRESS;"
    "DATABASE=Directory.Data;"
    "Trusted_Connection=yes;"
    "TrustServerCertificate=yes;"
)

print("Connected successfully!")
# Out:
# Connected successfully!

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ASUS\Downloads\directory.csv")

print(df.head())
print(df.columns)
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
# %pip install sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 505.6 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.1 MB 505.6 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.1 MB 505.6 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.1 MB 505.6 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 380.2 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 380.2 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 380.2 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.1 MB 409.7 kB/s eta 0:00:03
# ...

# %%
from sqlalchemy import create_engine

print("SQLAlchemy installed successfully!")
# Out:
# SQLAlchemy installed successfully!

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ASUS\Downloads\directory.csv")

# Check the data
print(df.head())
print(df.shape)
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
from sqlalchemy import create_engine
import urllib

# %%
from sqlalchemy import create_engine
import urllib

conn_str = (
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=.\\SQLEXPRESS;"
    "DATABASE=Directory.Data;"
    "Trusted_Connection=yes;"
    "TrustServerCertificate=yes;"
)

params = urllib.parse.quote_plus(conn_str)

engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

# %%
df.to_sql(
    name="directory",
    con=engine,
    if_exists="replace",   # Creates or replaces the table
    index=False
)

print("✅ CSV imported successfully!")
# Out:
# ✅ CSV imported successfully!
